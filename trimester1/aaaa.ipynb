# %% [markdown]
# Markdown-cel
#
# # Titel
#
# ## Ondertitel
# **vet**
# *cursief*
# - opsomming
# - opsomming
# -
# 1. item
# 2. item fdfksdjkfjd
# `print(iets)`
#
# [schoolsite](https://www.sivibu.be)

# %%
# code-cel
naam = input('Wat is je naam')
print('Dag',naam)
# Out:
# Wat is je naamIngrid
# Dag Ingrid
