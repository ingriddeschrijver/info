# %%
print(16**0.5 - 2 * 3 + 5)
print(5 * 2)
# Out:
# 3.0
# 10

# %%
bananen = 100
print(bananen)
# Out:
# 100

# %%
bananen = 100
bananen = bananen + 5
print(bananen)
# Out:
# 105

# %%
bananen = 100
bananen /= 5
print(bananen)
# Out:
# 20.0

# %%
bananen = 102
dozen = bananen // 5
rest = bananen % 5
prijs = dozen * 20.5
print(dozen, type(dozen))
print(rest, type(rest))
print(prijs, type(prijs))
# Out:
# 20 <class 'int'>
# 2 <class 'int'>
# 410.0 <class 'float'>

# %%
aantal_snoepjes = 40
aantal_leerlingen = 12
a = aantal_snoepjes // aantal_leerlingen
b = aantal_snoepjes % aantal_leerlingen
print(f' a = {a} en b = {b}')
# Out:
#  a = 3 en b = 4

# %%
# volgorde bewerking - wissel lijn 3 en 4 om
getal = 102
a = getal // 5
b = a % 7
print(f' a = {a} en b = {b}')
# Out:
#  a = 20 en b = 6

# %%
a ='5'
b = '3'
print(a+b)
# Out:
# 53

# %%
a = '5'
print(type(a))
# Out:
# <class 'str'>

# %%
woord_1 = 'voet'
woord_2 = 'bal'
samenstelling = woord_1 + woord_2
print(samenstelling)
# Out:
# voetbal

# %%
a = 12
b = 10
propositie = a > b
print(propositie)
# Out:
# True

# %%
a = 12
b = 10
c = 5
print(a != b) 
print(not (a < c)) 
print(a > b or a < c and b < c)
# Out:
# True
# True
# True

# %%
bewering_1  = 5 > 3 and 5 == 3 + 2
print(bewering_1) 
bewering_2  = 5 < 3 or 5 == 3 + 2
print(bewering_2) 
bewering_3  = 5 < 3 and 5 != 3 + 2
print(bewering_3)
# Out:
# True
# True
# False

# %%
x = 4
if x > 5:
    print('a')
else:
    print('b')
print('c')
# Out:
# b
# c

# %%
for getal in range(11,20,3):
    print(getal)
# Out:
# 11
# 14
# 17

# %%
x = 3
while x <= 5:
    print(x + 12)
    x = x + 1
print(x)
# Out:
# 15
# 16
# 17
# 6

# %%
lijst = ['a','b','c','d']
for item in lijst:
    print(2*item , end ='+')
# Out:
# aa+bb+cc+dd+

# %%
tekst = "Superformiweldigfantakolosachtig"
print(tekst[5:10])
# Out:
# formi
