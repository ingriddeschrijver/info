# %%
lijst = ['aap', 'giraf','tijger','leeuw','olifant','nijlpaard']
for dier in lijst:
    eerste_letter = dier[0]
    print(eerste_letter)

# %%
for getal in range(5):
    print(getal**2 , end = ' | ')

# %%
lijst = ['aap', 'giraf','tijger','leeuw','olifant','nijlpaard']
aantal_elementen_lijst = len(lijst)
index = 0
while index < len(lijst):
    dier = lijst[index]
    print(dier[0])
    index += 1

# %%
getal = 0
while getal < 5:
    print(getal**2 , end = ' | ')
    getal += 1

# %%
# probleem!!!!
getal = 0
while getal < 5:
    print(getal**2)

# %%
print('Berekenen van de som van een aantal getallen')
som = 0 
invoer = 0
while invoer != 'S':
    som = som + int(invoer)
    print(f'De voorlopige som is nu {som}.')
    invoer = input('Geef een natuurlijk getal, stop door S te tikken: ')
print(f'De totale som is {som}.')

# %%
# Veel voorkomende problemen bij een while-lus = voorwaardelijke herhaling.
# BIJ HET TESTEN - NA ELKE UITVOERING: 
#                      Noyau/Redémarrer & effacer les sorties
# Je stopt op die manier de kernel: alle geheugenplaatsen worden verwijderd.
# Pas de code aan zodat het werkt.
print('Maken van een woord')
woord = ''

while letter != 0:
    letter = input('Geef een letter van het woord, stop door 0 te tikken: ')
    woord += letter
    
print(f'Het volledige woord is {woord}.')
