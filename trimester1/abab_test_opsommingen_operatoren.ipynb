# %%
dieren = ["kat", "hond", "konijn", "vis", "hamster"]
print(dieren[2])

# %%
dieren = ["kat", "hond", "konijn", "vis", "hamster"]
print(dieren[-1])

# %%
dieren = ["kat", "hond", "konijn", "vis", "hamster"]
print(dieren[1:3])

# %%
dieren = ["kat", "hond", "konijn", "vis", "hamster"]
print(dieren[:2])

# %%
dieren = ["kat", "hond", "konijn", "vis", "hamster"]
print(len(dieren))

# %%
groep1 = ["kat", "hond"]
groep2 = ["vis", "hamster"]
print(groep1 + groep2)

# %%
getallen = [9, 2, 7, 4, 1]
getallen.sort()
getallen.remove(2)
getallen.append(10)
getallen.pop()
print(getallen)

# %%
rgb = (250, 128, 0)
print(rgb[1])

# %%
getallen = list(range(3, 15, 4))
print(getallen)

# %%
woord = "computer"
print(woord[3])

# %%
woord = "computer"
print(woord[2:5])

# %%
deel1 = "wereld"
deel2 = "wijd"
print(deel1 + deel2)

# %%
tekst = "Ik hou van kattenn"
print(tekst.replace("kattenn", "honden"))

# %%
zin = "Python is leuk om te leren"
print(zin.split())

# %%
a = 15
b = 9
print(a >= b)

# %%
taal = "NEDERLANDS"
print(taal == "nederlands")

# %%
klas = ["Sam", "Noor", "Ali", "Zoe"]
print("Ali" in klas)

# %%
klas = ["Sam", "Noor", "Ali", "Zoe"]
print("Mo" not in klas)

# %%
leeftijd = 16
lengte = 170
print(leeftijd >= 12 and lengte > 180)

# %%
leeftijd = 16
lengte = 170
print(leeftijd >= 18 or lengte > 150)

# %%
klaar = False
print(not klaar)

# %%
a = 5
b = 12
print(a < 10 and b < 10 or a == 5)

# %%
score = 10
score += 5
score *= 2
print(score)

# %%
print(17 / 4)
print(17 // 4)
print(17 % 4)

# %%
print(2 + 3 * 4 ** 2)

# %%
import math
print(math.sqrt(81))
print(math.pi)

# %%
from math import sqrt, pi
print(sqrt(49), pi > 3)
