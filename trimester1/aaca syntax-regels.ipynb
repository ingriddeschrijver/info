# %% [markdown]
# Syntax-regels

# %%
getal = 5
getal = getal * 2
getal *= 3
print(getal)

# %%
tekst = 'Basthon'
eerste_letter = tekst[0]
print(eerste_letter)

lengte_tekst = len(tekst)
print('De lengte van de tekst is',lengte_tekst)

laatste_letter = tekst[-1]
print(laatste_letter)

zin =  tekst + 'werkt goed'
print(zin)

# %%
print(zin[3])

# %%
zin[3] = 'p'
print(zin)
