# %%
rij_getallen = range(3,21,5)
print(rij_getallen)

lijst_getallen = [3, 8, 13, 18]
print(lijst_getallen)
# Out:
# range(3, 21, 5)
# [3, 8, 13, 18]

# %%
for getal in rij_getallen:
    print(getal)
print('--------------')
for getal in lijst_getallen:
    print(getal)
# Out:
# 3
# 8
# 13
# 18
# --------------
# 3
# 8
# 13
# 18
