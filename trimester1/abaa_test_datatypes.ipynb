# %%
vak = "Python"
print(type(vak))

# %%
aantal_lln = 24
print(type(aantal_lln))

# %%
gemiddelde = 7.5
print(type(gemiddelde))

# %%
score = 8.9
print(int(score))

# %%
deel1 = "leer"
deel2 = "kracht"
print(deel1 + deel2)

# %%
klas = "3A"
aantal = 22
print(klas, aantal)

# %%
klas = "3A"
aantal = 22
print(klas + aantal)

# %%
cijfer_tekst = "15"
cijfer_getal = int(cijfer_tekst)
print(cijfer_getal + 5)

# %%
punten = 18
zin = "Je hebt " + str(punten) + " punten."
print(zin)

# %%
antwoord = input("Wat is je lievelingskleur? ")
print(type(antwoord))

# %%
leeftijd = int(input("Hoe oud ben je? "))
print(type(leeftijd))

# %%
a = 12
b = 7
print(a > b)

# %%
woord = "python"
print(woord == "Python")

# %%
print(True + True)

# %%
print(False == 0)

# %%
resultaat = 10 != 10
print(resultaat, type(resultaat))

# %%
uitkomst = None
print(type(uitkomst))

# %%
uitkomst = None
print(uitkomst == None)

# %%
print(type(20 / 4))
print(type(20 // 4))
